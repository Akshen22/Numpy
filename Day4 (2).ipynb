# %% [raw]
# 1) pd.concat([A, B]): concat 2 df
# 2) pd.concat([A, B], ignore_index=True): after concat 2 df, default index will not occur 0,1 again
# 3) newdf = pd.concat([A, B], keys = ["Apple", "Windows"] ): A= Apple, B= Windows
# 4) B = pd.DataFrame({"PID" : [105, 106],
#                  "Product_Name"   : ["E", "F"]})
# -> give new column Product_Name,later when you concat A, B: B's name will be nan, A's product_name will be nan
# 5) pd.concat([A,B], axis=1): nan value will combine, B's name will be nan, A's product_name will be nan
# 6) D["PID"] = D["PID"].astype("int"): change the type of the data to int
#
# merge:
# 7) pd.merge(left   = D  ,
#         right = df  ,
#         on = "PID" )
# -> took D, df as we take it in from sql on PID, joins, and when its not written it is inner join
# 8) pd.merge(left   = D  ,
#         right = df ,
#         on = "PID",
#         how = "left")
# -> joins it on D taking all D's PID and common from df
# 9) viceversa with how= 'right'
# 10) how= 'outer': all
# 11) pd.merge(left   = D  ,right = df,
#          left_on = "PID", right_on = "ProductID"): as it as common values
# 12) pd.merge(left = D, right = df,
#         on = "PID", how = "inner",
#         suffixes = ("_product", "_place"))
#
# joins:
# 13) df.rename(columns = {"Name" : "Location"}, inplace=True)
# 14) D.join(df,
# lsuffix = "_product",
# rsuffix = "_store",
# how = "inner"
# D: PID->PID_product, df: PID->PID_store
#
# replace:
# 15) df["Location"].replace(to_replace = ["BLR","CHN"], value = ["Bangalore", "Chennai"], inplace=True)
# 16) df["Location"].map( { "Bangalore"  : "BLR" , "Chennai" : "CHN"}, inplace=True  )
# 17) tip["total_bill"].replace(lambda x : "above_avg"  if x > 19.78 else "less_eq_average")
#
# 18) duplicates:
# a) df_stud.duplicated(subset = "ID", keep = "last")
# b) df_stud.drop_duplicates(subset = "ID", keep = "last")
#
# 19) Missing values:
# a) titanic.isnull().sum()
# b) titanic.fillna("Unknown", axis=1)
# c) titanic.dropna(axis=1, inplace=True)
#
# 20) Plot:
# import matplotlib.pyplot as plt
# plt.grid()
# plt.plot(app["Day"],
#          app["App_price"], color = "red",linewidth = 2, label = "APP", marker = "*", ls = "--")
# plt.plot(app["Day"],
#          app["MSFT_price"], color = "black",linewidth = 2, label = "MSFT", marker = "*", ls = "--")
# plt.xlabel("Day")
# plt.ylabel("Price")
# plt.title("Apple stock prices")
# plt.savefig("Appl_stock.png")
# plt.legend()
# plt.show()

# %%
import pandas as pd

# %%
A = pd.DataFrame(  {"PID" : [101,102,103,104],
                   "Name"   : ["A", "B", "C", "D"]} )
A
# Out:
#    PID Name
# 0  101    A
# 1  102    B
# 2  103    C
# 3  104    D

# %%
B = pd.DataFrame({"PID" : [105, 106],
                 "Name"   : ["E", "F"]})
B
# Out:
#    PID Name
# 0  105    E
# 1  106    F

# %%
pd.concat([A, B])
# Out:
#    PID Name
# 0  101    A
# 1  102    B
# 2  103    C
# 3  104    D
# 0  105    E
# 1  106    F

# %%
pd.concat([A, B], ignore_index=True)
# Out:
#    PID Name
# 0  101    A
# 1  102    B
# 2  103    C
# 3  104    D
# 4  105    E
# 5  106    F

# %%
newdf = pd.concat([A, B], keys = ["Apple", "Windows"] )
newdf
# Out:
#            PID Name
# Apple   0  101    A
#         1  102    B
#         2  103    C
#         3  104    D
# Windows 0  105    E
#         1  106    F

# %%
newdf.index
# Out:
# MultiIndex([(  'Apple', 0),
#             (  'Apple', 1),
#             (  'Apple', 2),
#             (  'Apple', 3),
#             ('Windows', 0),
#             ('Windows', 1)],
#            )

# %%
A
# Out:
#    PID Name
# 0  101    A
# 1  102    B
# 2  103    C
# 3  104    D

# %%
B = pd.DataFrame({"PID" : [105, 106],
                 "Product_Name"   : ["E", "F"]})
B
# Out:
#    PID Product_Name
# 0  105            E
# 1  106            F

# %%
pd.concat([A,B])
# Out:
#    PID Name Product_Name
# 0  101    A          NaN
# 1  102    B          NaN
# 2  103    C          NaN
# 3  104    D          NaN
# 0  105  NaN            E
# 1  106  NaN            F

# %%
pd.concat([A,B], axis=1)
# Out:
#    PID Name    PID Product_Name
# 0  101    A  105.0            E
# 1  102    B  106.0            F
# 2  103    C    NaN          NaN
# 3  104    D    NaN          NaN

# %%
A
# Out:
#    PID Name
# 0  101    A
# 1  102    B
# 2  103    C
# 3  104    D

# %%
B = pd.DataFrame({"PID" : [105, 106],
                 "Name"   : ["E", "F"]})
B
# Out:
#    PID Name
# 0  105    E
# 1  106    F

# %%
pd.concat([A,B], axis=1)
# Out:
#    PID Name    PID Name
# 0  101    A  105.0    E
# 1  102    B  106.0    F
# 2  103    C    NaN  NaN
# 3  104    D    NaN  NaN

# %%
C = pd.DataFrame( {"Location" : ["MuM", "BLR", "CHN"]})
C
# Out:
#   Location
# 0      MuM
# 1      BLR
# 2      CHN

# %%
A
# Out:
#    PID Name
# 0  101    A
# 1  102    B
# 2  103    C
# 3  104    D

# %%
pd.concat([A,C], axis=1 )
# Out:
#    PID Name Location
# 0  101    A      MuM
# 1  102    B      BLR
# 2  103    C      CHN
# 3  104    D      NaN

# %%
B = pd.DataFrame({"PID" : ["105", "106"],
                 "Name"   : ["E", "F"]})
B
# Out:
#    PID Name
# 0  105    E
# 1  106    F

# %%
D = pd.concat([A,B])
print(D.dtypes)
print(D)
# Out:
# PID     object
# Name    object
# dtype: object
#    PID Name
# 0  101    A
# 1  102    B
# 2  103    C
# 3  104    D
# 0  105    E
# 1  106    F

# %%
D["PID"] = D["PID"].astype("int")
D.dtypes
# Out:
# PID      int32
# Name    object
# dtype: object

# %%
D = pd.concat([A,B], ignore_index=True)
D["PID"] = D["PID"].astype("int")
print(D)
# Out:
#    PID Name
# 0  101    A
# 1  102    B
# 2  103    C
# 3  104    D
# 4  105    E
# 5  106    F

# %%
D["Price"] = [12,13,10,8,9,15]
D
# Out:
#    PID Name  Price
# 0  101    A     12
# 1  102    B     13
# 2  103    C     10
# 3  104    D      8
# 4  105    E      9
# 5  106    F     15

# %%
# merge
df = pd.DataFrame( { "SID" : ["S101", "S102", "S101","S101", "S102"],
                   "PID" : [101, 102, 103, 105 , 107],
                   "Location" : ["BLR", "CHN","CHN","BLR","BLR"]})
df
# Out:
#     SID  PID Location
# 0  S101  101      BLR
# 1  S102  102      CHN
# 2  S101  103      CHN
# 3  S101  105      BLR
# 4  S102  107      BLR

# %%
D
# Out:
#    PID Name  Price
# 0  101    A     12
# 1  102    B     13
# 2  103    C     10
# 3  104    D      8
# 4  105    E      9
# 5  106    F     15

# %%
df
# Out:
#     SID  PID Location
# 0  S101  101      BLR
# 1  S102  102      CHN
# 2  S101  103      CHN
# 3  S101  105      BLR
# 4  S102  107      BLR

# %%
pd.merge(left   = D  ,
        right = df  ,
        on = "PID" ) #inner join
# Out:
#    PID Name  Price   SID Location
# 0  101    A     12  S101      BLR
# 1  102    B     13  S102      CHN
# 2  103    C     10  S101      CHN
# 3  105    E      9  S101      BLR

# %%
pd.merge(left   = D  ,
        right = df ,
        on = "PID",
        how = "left")
# Out:
#    PID Name  Price   SID Location
# 0  101    A     12  S101      BLR
# 1  102    B     13  S102      CHN
# 2  103    C     10  S101      CHN
# 3  104    D      8   NaN      NaN
# 4  105    E      9  S101      BLR
# 5  106    F     15   NaN      NaN

# %%
pd.merge(left   = D  ,
        right = df ,
        on = "PID",
        how = "right")
# Out:
#    PID Name  Price   SID Location
# 0  101    A   12.0  S101      BLR
# 1  102    B   13.0  S102      CHN
# 2  103    C   10.0  S101      CHN
# 3  105    E    9.0  S101      BLR
# 4  107  NaN    NaN  S102      BLR

# %%
pd.merge(left   = D  ,
        right = df ,
        on = "PID",
        how = "outer")
# Out:
#    PID Name  Price   SID Location
# 0  101    A   12.0  S101      BLR
# 1  102    B   13.0  S102      CHN
# 2  103    C   10.0  S101      CHN
# 3  104    D    8.0   NaN      NaN
# 4  105    E    9.0  S101      BLR
# 5  106    F   15.0   NaN      NaN
# 6  107  NaN    NaN  S102      BLR

# %%
# merge
df = pd.DataFrame( { "SID" : ["S101", "S102", "S101","S101", "S102"],
                   "ProductID" : [101, 102, 103, 105 , 107],
                   "Location" : ["BLR", "CHN","CHN","BLR","BLR"]})
df
# Out:
#     SID  ProductID Location
# 0  S101        101      BLR
# 1  S102        102      CHN
# 2  S101        103      CHN
# 3  S101        105      BLR
# 4  S102        107      BLR

# %%
D
# Out:
#    PID Name  Price
# 0  101    A     12
# 1  102    B     13
# 2  103    C     10
# 3  104    D      8
# 4  105    E      9
# 5  106    F     15

# %%
pd.merge(left   = D  ,right = df,
         left_on = "PID", right_on = "ProductID")
# Out:
#    PID Name  Price   SID  ProductID Location
# 0  101    A     12  S101        101      BLR
# 1  102    B     13  S102        102      CHN
# 2  103    C     10  S101        103      CHN
# 3  105    E      9  S101        105      BLR

# %%
# merge
df = pd.DataFrame( { "SID" : ["S101", "S102", "S101","S101", "S102"],
                   "PID" : [101, 102, 103, 105 , 107],
                   "Name" : ["BLR", "CHN","CHN","BLR","BLR"]})
df
# Out:
#     SID  PID Name
# 0  S101  101  BLR
# 1  S102  102  CHN
# 2  S101  103  CHN
# 3  S101  105  BLR
# 4  S102  107  BLR

# %%
D
# Out:
#    PID Name  Price
# 0  101    A     12
# 1  102    B     13
# 2  103    C     10
# 3  104    D      8
# 4  105    E      9
# 5  106    F     15

# %%
pd.merge(left = D, right = df,
        on = "PID", how = "inner")
# Out:
#    PID Name_x  Price   SID Name_y
# 0  101      A     12  S101    BLR
# 1  102      B     13  S102    CHN
# 2  103      C     10  S101    CHN
# 3  105      E      9  S101    BLR

# %%
pd.merge(left = D, right = df,
        on = "PID", how = "inner",
        suffixes = ("_product", "_place"))
# Out:
#    PID Name_product  Price   SID Name_place
# 0  101            A     12  S101        BLR
# 1  102            B     13  S102        CHN
# 2  103            C     10  S101        CHN
# 3  105            E      9  S101        BLR

# %%
# join
D
# Out:
#    PID Name  Price
# 0  101    A     12
# 1  102    B     13
# 2  103    C     10
# 3  104    D      8
# 4  105    E      9
# 5  106    F     15

# %%
df.rename(columns = {"Name" : "Location"}, inplace=True)
df
# Out:
#     SID  PID Location
# 0  S101  101      BLR
# 1  S102  102      CHN
# 2  S101  103      CHN
# 3  S101  105      BLR
# 4  S102  107      BLR

# %%
D.join(df, 
       lsuffix = "_product", 
       rsuffix = "_store" )  # left join by default, based on index
# Out:
#    PID_product Name  Price   SID  PID_store Location
# 0          101    A     12  S101      101.0      BLR
# 1          102    B     13  S102      102.0      CHN
# 2          103    C     10  S101      103.0      CHN
# 3          104    D      8  S101      105.0      BLR
# 4          105    E      9  S102      107.0      BLR
# 5          106    F     15   NaN        NaN      NaN

# %%
# 101	A	12   S101	101	BLR
# 102	B	13   S102	102	CHN
# 103	C	10   S101	103	CHN
# 104	D	8    S101	105	BLR

# %%
D.set_index("PID", inplace=True)
df.set_index("PID", inplace=True)

# %%
D.join(df, lsuffix = "_product", rsuffix = "_store" )  # left join by default, based on index
# Out:
#     Name  Price   SID Location
# PID
# 101    A     12  S101      BLR
# 102    B     13  S102      CHN
# 103    C     10  S101      CHN
# 104    D      8   NaN      NaN
# 105    E      9  S101      BLR
# 106    F     15   NaN      NaN

# %%
D.join(df, lsuffix = "_product", rsuffix = "_store",
      how = "inner")  # left join by default, based on index
# Out:
#     Name  Price   SID Location
# PID
# 101    A     12  S101      BLR
# 102    B     13  S102      CHN
# 103    C     10  S101      CHN
# 105    E      9  S101      BLR

# %%
D.join(df, lsuffix = "_product", rsuffix = "_store",
      how = "right")  # left join by default, based on index
# Out:
#     Name  Price   SID Location
# PID
# 101    A   12.0  S101      BLR
# 102    B   13.0  S102      CHN
# 103    C   10.0  S101      CHN
# 105    E    9.0  S101      BLR
# 107  NaN    NaN  S102      BLR

# %%
D.join(df, lsuffix = "_product", rsuffix = "_store",
      how = "outer")  # left join by default, based on index
# Out:
#     Name  Price   SID Location
# PID
# 101    A   12.0  S101      BLR
# 102    B   13.0  S102      CHN
# 103    C   10.0  S101      CHN
# 104    D    8.0   NaN      NaN
# 105    E    9.0  S101      BLR
# 106    F   15.0   NaN      NaN
# 107  NaN    NaN  S102      BLR

# %%
df.reset_index(inplace=True)

# %%
df["Location"].replace(to_replace = ["BLR","CHN"],
                      value = ["Bangalore", "Chennai"], inplace=True)
df
# Out:
#    PID   SID   Location
# 0  101  S101  Bangalore
# 1  102  S102    Chennai
# 2  103  S101    Chennai
# 3  105  S101  Bangalore
# 4  107  S102  Bangalore

# %%
df["Location"].replace(to_replace = ["Bangalore","Chennai"],
                      value = ["BLR"], inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 df["Location"].replace(to_replace = ["Bangalore","Chennai"],
#       2                       value = ["BLR"], inplace=True)
#       3 df
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:5380, in Series.replace(self, to_replace, value, inplace, limit, regex, method)
#    5362 @deprecate_nonkeyword_arguments(
# ...

# %%
df["Location"].replace(to_replace = ["Bangalore","Chennai"],
                      value = ["BLR","CHN"], inplace=True)
df

# %%
df["Location"].replace(to_replace = ["BLR","CHN","MUM"],
                      value = ["Bangalore","Chennai","Mumbai"], 
                       inplace=True)
df

# %%
df["Location"].map( { "Bangalore"  : "BLR" , "Chennai" : "CHN" }  )

# %%
df["Location"].map( { "Bangalore"  : "BLR" , "Chennai" : "CHN",
                    "Mumbai" : "MUM"}, inplace=True  )

# %%
import seaborn as sns
tip = sns.load_dataset("tips")
tip.head()

# %%
tip["smoker"].replace(  to_replace = ["Yes", "No"],
                    value = [1, 0])

# %%
tip["total_bill"].mean()

# %%
func = lambda x : "above_avg"  if x > 19.78 else "less_eq_average"
func(10)

# %%
tip["bill_bucket"] = tip["total_bill"].map(lambda x : "above_avg"  if x > 19.78 else "less_eq_average")

# %%
tip["total_bill"].replace(lambda x : "above_avg"  if x > 19.78 else "less_eq_average")

# %%
# duplicates

stud = {"ID" : [101,102,103,104,101,101,102],
       "Marks" : [24, 22, 34, 32, 24,25,23  ]}
df_stud = pd.DataFrame(stud)
df_stud

# %%
df_stud.duplicated()

# %%
df_stud[df_stud.duplicated()]

# %%
df_stud[~df_stud.duplicated()]

# %%
df_stud.duplicated(keep = "last")

# %%
df_stud

# %%
df_stud.duplicated(subset = "ID")

# %%
df_stud.duplicated(subset = "ID", 
                   keep = "last")

# %%
df_stud.drop_duplicates()

# %%
df_stud.drop_duplicates(subset = "ID")

# %%
df_stud.drop_duplicates(subset = "ID",
                        keep = "last")

# %%
# handling missing values
titanic = sns.load_dataset("titanic")
titanic.head()

# %%
titanic.shape

# %%
titanic.isnull()

# %%
sum(  [True, False, True] )

# %%
titanic.isnull().sum()

# %%
titanic.fillna("Unknown", axis=1)

# %%
titanic.dropna()

# %%
titanic.dropna(axis=1, inplace=True)

# %%
titanic

# %%
app = pd.DataFrame(  {"Day" : ["Day1", "Day2", "Day3","Day4", "Day5"],
                     "Price" : [110, 90, 105, 108, 97]})
app

# %%
import matplotlib.pyplot as plt
plt.plot(app["Day"], app["Price"])

# %%
import matplotlib.pyplot as plt
plt.plot(app["Day"], app["Price"])
plt.xlabel("Day")
plt.ylabel("Price")

# %%
import matplotlib.pyplot as plt
plt.plot(app["Day"], app["Price"])
plt.xlabel("Day")
plt.ylabel("Price")
plt.title("Apple stock prices")

# %%
import matplotlib.pyplot as plt
plt.plot(app["Day"], 
         app["Price"], color = "red")

plt.xlabel("Day")
plt.ylabel("Price")
plt.title("Apple stock prices")

# %%
import matplotlib.pyplot as plt
plt.plot(app["Day"], 
         app["Price"], color = "red",
        marker = "*")
plt.xlabel("Day")
plt.ylabel("Price")
plt.title("Apple stock prices")

# %%
import matplotlib.pyplot as plt
plt.plot(app["Day"], 
         app["Price"], color = "red",
        marker = "*", ls = "--")
plt.xlabel("Day")
plt.ylabel("Price")
plt.title("Apple stock prices")

# %%
import matplotlib.pyplot as plt
plt.plot(app["Day"], 
         app["Price"], color = "red",linewidth = 2)

plt.xlabel("Day")
plt.ylabel("Price")
plt.title("Apple stock prices")

# %%
import matplotlib.pyplot as plt
plt.grid()
plt.plot(app["Day"], 
         app["Price"], color = "red",linewidth = 2,
         marker = "*", ls = "--")
plt.xlabel("Day")
plt.ylabel("Price")
plt.title("Apple stock prices")
plt.savefig("Appl_stock.png")
plt.show()

# %%
plt.plot(app["Day"], 
         app["Price"], color = "red",linewidth = 2)

plt.xlabel("Day")
plt.ylabel("Price")
plt.title("Apple stock prices")

plt.savefig("Appl_stock.png")
plt.show()

# %%
plt.grid()
plt.plot(app["Day"], 
         app["Price"], color = "red",linewidth = 2)
plt.xlabel("Day")
plt.ylabel("Price")
plt.title("Apple stock prices")

plt.savefig("Appl_stock.png")
plt.show()

# %%
app.rename(columns = {"Price" : "App_price"}, inplace=True)

# %%
app["MSFT_price"] = [102, 109, 98, 95, 104]
app

# %%
import matplotlib.pyplot as plt
plt.grid()
plt.plot(app["Day"], 
         app["Price"], color = "red",linewidth = 2,
         marker = "*", ls = "--")
plt.xlabel("Day")
plt.ylabel("Price")
plt.title("Apple stock prices")
plt.savefig("Appl_stock.png")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.grid()
plt.plot(app["Day"], 
         app["App_price"], color = "red",linewidth = 2, label = "APP")
plt.plot(app["Day"], 
         app["MSFT_price"], color = "black",linewidth = 2, label = "MSFT")
plt.xlabel("Day")
plt.ylabel("Price")
plt.title("stock prices")
plt.legend()
plt.show()
